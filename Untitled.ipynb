# %%
import gensim

# Load Google's pre-trained Word2Vec model.
model = gensim.models.KeyedVectors.load_word2vec_format('./GoogleNews-vectors-negative300.bin', binary=True)

# %%
import pandas as pd

# %%
tags = pd.read_csv('data/tags.csv')

# %%
tags.tail(500)
# Out:
#        tag_id               tag_name
# 33752   33752             رضوى_عاشور
# 33753   33753             رضوي-عاشور
# 33754   33754                    رعب
# 33755   33755         رعب-حسن-الجندي
# 33756   33756               رعب-ساخر
# 33757   33757          رعب-غموض-خيال
# 33758   33758             رغم-الفراق
# 33759   33759                  رقائق
# 33760   33760                   رمان
# 33761   33761            رمان-ایرانی
# 33762   33762            رمان-تاریخی
# 33763   33763             رمان-خارجی
# 33764   33764            رمان-داستان
# 33765   33765             رمان-فارسی
# 33766   33766          رمان-و-داستان
# 33767   33767   رمان-و-داستان-ایرانی
# 33768   33768    رمان-و-داستان-كوتاه
# 33769   33769    رمان-و-داستان-کوتاه
# 33770   33770                  رمضان
# 33771   33771                 روآيآت
# 33772   33772                  روائع
# 33773   33773  روائع-من-الادب-العربي
# 33774   33774                  روائي
# 33775   33775             روان-شناسی
# ...

# %%
model.get_vector('nonfiction')
# Out:
# array([ -4.39453125e-02,  -1.55029297e-02,  -1.76757812e-01,
#          1.77734375e-01,   5.76171875e-02,  -2.45117188e-01,
#          5.73730469e-02,   2.39257812e-01,   1.12792969e-01,
#         -3.00781250e-01,   3.69140625e-01,   1.41601562e-01,
#          3.75000000e-01,   8.59375000e-02,   7.12890625e-02,
#         -9.71679688e-02,  -1.68945312e-01,  -2.15820312e-01,
#          1.52343750e-01,  -1.49414062e-01,  -1.06933594e-01,
#         -1.98242188e-01,   3.12500000e-02,   3.06396484e-02,
#         -2.36328125e-01,  -2.29492188e-01,  -7.17773438e-02,
#          3.14453125e-01,  -5.93261719e-02,  -1.37695312e-01,
#         -4.78515625e-01,  -3.41796875e-02,  -3.32031250e-01,
#          1.04492188e-01,   2.50000000e-01,  -3.66210938e-02,
#         -1.10839844e-01,  -1.01562500e-01,   2.53906250e-01,
#          2.75390625e-01,   2.32421875e-01,  -1.94091797e-02,
#         -3.93066406e-02,   3.18359375e-01,  -3.33984375e-01,
# ...
